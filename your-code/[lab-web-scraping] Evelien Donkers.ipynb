# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  # Check documentation to specify 'features'
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-481a47a96965f6706fb41bae0d14b09a.css" integrity="sha512-/YEVWs7BzxfKyUd6zVxjEQcXRWsLbcEjv045Rq8DSoipySmQblhVKxlXLva2GtNd5DhwCxHwW1RM0N9I7S2Vew==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
Tr_Dev = soup.find_all('h1', attrs = {'class': 'h3 lh-condensed'})
Mt_Dev = soup.find_all('p', attrs = {'class': 'f4 text-normal mb-1'})

# %%
tags = ['h1']
text2 = [element.text for element in Tr_Dev]

# %%
tags = ['p']
text3 = [element.text.replace("\n", "") for element in Mt_Dev]
text4 = [element.replace("              ", "(") for element in text3]
text4 = list(map(lambda x: x + ")", text4))

# %%
text5 = [element.text.replace("\n", "") for element in Tr_Dev]
text6 = [element.replace("            ", "") for element in text5]
text6
# Out:
# ['Gregor Santner',
#  'Ayke',
#  'Francois Zaninotto',
#  'David Rodríguez',
#  'Emmanuel Garcia',
#  'Hugo van Kemenade',
#  '文翼',
#  'XhmikosR',
#  'Alex Gaynor',
#  'Michael Schurter',
#  'Juliette',
#  'Piotrek Witek',
#  'Daniel Imms',
#  'TJ Holowaychuk',
#  'Joshua Tauberer',
#  'Chris Ross',
#  'Kazuho Oku',
#  'Chris Banes',
#  'Ron Buckton',
#  'Kamil Kisiela',
#  'Miguel Mota',
#  'Michiel Borkent',
#  'Koen Kanters',
#  'Hongbo Zhang',
#  'Wojciech Maj']

# %%
text7 = list(zip(text6,text4))

# %%
list(map(lambda x: " ".join(x), text7))
# Out:
# ['Gregor Santner (gsantner)',
#  'Ayke (aykevl)',
#  'Francois Zaninotto (fzaninotto)',
#  'David Rodríguez (deivid-rodriguez)',
#  'Emmanuel Garcia (blasten)',
#  'Hugo van Kemenade (hugovk)',
#  '文翼 (wenzhixin)',
#  'XhmikosR (alex)',
#  'Alex Gaynor (schmichael)',
#  'Michael Schurter (jrfnl)',
#  'Juliette (piotrwitek)',
#  'Piotrek Witek (Tyriar)',
#  'Daniel Imms (tj)',
#  'TJ Holowaychuk (JoshData)',
#  'Joshua Tauberer (Tratcher)',
#  'Chris Ross (kazuho)',
#  'Kazuho Oku (chrisbanes)',
#  'Chris Banes (rbuckton)',
#  'Ron Buckton (kamilkisiela)',
#  'Kamil Kisiela (miguelmota)',
#  'Miguel Mota (borkdude)',
#  'Michiel Borkent (Koenkk)',
#  'Koen Kanters (bobzhang)',
#  'Hongbo Zhang (wojtekmaj)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-481a47a96965f6706fb41bae0d14b09a.css" integrity="sha512-/YEVWs7BzxfKyUd6zVxjEQcXRWsLbcEjv045Rq8DSoipySmQblhVKxlXLva2GtNd5DhwCxHwW1RM0N9I7S2Vew==" media="all" rel="stylesheet"/>
# ...

# %%
Find_info = soup.find_all('h1', attrs = {'class': 'h3 lh-condensed'})

tags = ['a']
text8 = [element.text for element in Find_info]
text9 = [element.text.replace("\n", "") for element in Find_info]
text10 = [element.replace("/", "") for element in text9]
text11 = [element.replace("        ", "") for element in text10]
text12 = [element.replace("       ", "/") for element in text11]
text12
# Out:
# ['openai/gpt-2-output-dataset',
#  'openai/gpt-2',
#  'microsoft/DialoGPT',
#  'ansible/ansible',
#  'wistbean/learn_python3_spider',
#  'isocpp/CppCoreGuidelines',
#  '0xInfection/Awesome-WAF',
#  'huggingface/transformers',
#  'public-apis/public-apis',
#  'Azure/azure-cli',
#  'AceLewis/my_first_calculator.py',
#  'Unity-Technologies/ml-agents',
#  'pwn2winctf/2019',
#  'eastlakeside/interpy-zh',
#  'seleniumbase/SeleniumBase',
#  'docker/compose',
#  'Morizeyao/GPT2-Chinese',
#  'stellargraph/stellargraph',
#  'pfnet/optuna',
#  'apachecn/AiLearning',
#  'swisskyrepo/PayloadsAllTheThings',
#  'ros-industrial/universal_robot',
#  'mlflow/mlflow',
#  'getredash/redash',
#  'pandas-dev/pandas']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Walt Disney - Wikipedia</title>
# ...

# %%
soup.pretify

# %%
image_links =  [element.get('src') for element in soup.find_all('img')]


image_links
# Out:
# ['//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
# ...

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  
Find_titels = soup.find_all('div', attrs = {'class': 'usctitlechanged'})

# %%
text8 = [element.text for element in Find_titels]
text9 = [element.text.replace("\n", "") for element in Find_titels]
text10 = [element.replace("/", "") for element in text9]
text11 = [element.replace("  ", "") for element in text10]
text12 = [element.replace(" ٭", "") for element in text11]
text13 = ' '.join(text12)

# %%
print(text13.count('Title'),'titles are changed')
# Out:
# 2 titles are changed

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  
Most_wanted = soup.find_all('h3', attrs = {'class': 'title'})
text8 = [element.text for element in Most_wanted]
text9 = [element.text.replace("\n", "") for element in Most_wanted]
text10 = [element.replace("/", "") for element in text9]
text11 = [element.replace("  ", "") for element in text10]
text12 = [element.replace(" ٭", "") for element in text11]
text12
# Out:
# ['JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'EUGENE PALMER',
#  'SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ARNOLDO JIMENEZ',
#  'ALEJANDRO ROSALES CASTILLO',
#  'YASER ABDEL SAID']

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/handle'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  
Tweets = soup.find_all('span', attrs = {'class': 'ProfileNav-value'})
Tweets
# Out:
# [<span class="ProfileNav-value" data-count="11" data-is-compact="false">11
#              </span>,
#  <span class="ProfileNav-value">Mais <span class="ProfileNav-dropdownCaret Icon Icon--medium Icon--caretDown"></span></span>]

# %%
import re

Kinda_clean = [element.text for element in Tweets]
Find_numbers = re.findall('[0-9]+', ''.join(Kinda_clean))
Find_numbers
# Out:
# ['11']

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
url = 'https://twitter.com/EvelienDonkers'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  
Tweets_followers = soup.find_all('li', attrs = {'class': 'ProfileNav-item ProfileNav-item--followers'})
Tweets_followers

Kinda_clean = [element.text for element in Tweets_followers]
Find_numbers = re.findall('[0-9]+', ''.join(Kinda_clean))
Find_numbers
# Out:
# ['182']

# %%
# your code here

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  
Find_info = soup.find_all('a', attrs = {'class': 'link-box'})

# %%
text8 = [element.text for element in Find_info]
text9 = [element.text.replace("\n", " ") for element in Find_info]
text10 = [element.replace("\xa0", " ") for element in text9]
#text11 = [element.replace("xa", "") for element in text10]
#text12 = [element.replace("       ", "/") for element in text11]
list(text10)
# Out:
# [' English 5 964 000+ articles ',
#  ' Español 1 554 000+ artículos ',
#  ' 日本語 1 175 000+ 記事 ',
#  ' Deutsch 2 361 000+ Artikel ',
#  ' Русский 1 576 000+ статей ',
#  ' Français 2 152 000+ articles ',
#  ' Italiano 1 562 000+ voci ',
#  ' 中文 1 080 000+ 條目 ',
#  ' Português 1 014 000+ artigos ',
#  ' Polski 1 367 000+ haseł ']

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url2 = 'https://data.gov.uk/'

# %%
html = requests.get(url2).content
soup2 = BeautifulSoup(html, "lxml")  
soup2
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 9]><html class="lte-ie8" lang="en"><![endif]--><!--[if gt IE 8]><!--><html lang="en"><!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title>Find open data - data.gov.uk</title>
# <!--[if gt IE 8]><!--><link crossorigin="anonymous" href="/find-assets/govuk-template-0687f0d06ea9fff4c2f019429ababd62eb553c0e2ba67f1bba5c99d05b1755da.css" integrity="sha256-Bofw0G6p//TC8BlCmrq9YutVPA4rpn8bulyZ0FsXVdo=" media="screen" rel="stylesheet"/><!--<![endif]-->
# <!--[if IE 6]><link rel="stylesheet" media="screen" href="/find-assets/govuk-template-ie6-7dabc9dc229ba6baa65e0c758c7a9aaeba5e27be6adb119b7e2e8a78de7e0acb.css" /><![endif]-->
# <!--[if IE 7]><link rel="stylesheet" media="screen" href="/find-assets/govuk-template-ie7-aca92e08e156f534bd2173a42883e4f80ba249fcd691b7f7493f27ce143033ed.css" /><![endif]-->
# ...

# %%
Kind_of_data_sets = soup.find_all('div', attrs = {'class': 'column-one-third'})
text8 = [element.text for element in Kind_of_data_sets]
text9 = [element.text.replace("\n", " ") for element in Kind_of_data_sets]
text10 = [element.replace("    ", "") for element in text9]
text11 = [element.replace("  ", "") for element in text10]
#text12 = [element.replace("       ", "/") for element in text11]

text11
# Out:
# ['Business and economy Small businesses, industry, imports, exports and trade Crime and justice Courts, police, prison, offenders, borders and immigration Defence Armed forces, health and safety, search and rescue Education Students, training, qualifications and the National Curriculum',
#  'Environment Weather, flooding, rivers, air quality, geology and agriculture Government Staff numbers and pay, local councillors and department business plans Government spending Includes all payments by government departments over £25,000 Health Includes smoking, drugs, alcohol, medicine performance and hospitals',
#  'Mapping Addresses, boundaries, land ownership, aerial photographs, seabed and land terrain Society Employment, benefits, household finances, poverty and population Towns and cities Includes housing, urban planning, leisure, waste and energy, consumption Transport Airports, roads, freight, electric vehicles, parking, buses and footpaths']

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of languages by number of native speakers - Wikipedia
#   </title>
#   <script>
# ...

# %%
### can`t seem do make it pretty... 

My_table = [tr.text for tr in soup.find_all('tr')]

My_table = [element.replace("\n", " ") for element in My_table]
My_table = [row.strip().split(" \n") for row in My_table]

colnames = My_table[0]
data = top_10[1:11]

df = pd.DataFrame(data, columns=colnames)
df
# Out:
#   Rank  Language  Country of Origin  TotalCountries[a]  Speakers(millions)  % of the World population (March 2019)[8]   Language familyBranch
# 0  1\n\nMandarin [9]\n\nChina\n\n13\n\n918\n\n11....
# 1  2\n\nSpanish\n\nSpain\n\n31\n\n480\n\n5.994\n\...
# 2  3\n\nEnglish\n\nUnited Kingdom\n\n137\n\n379\n...
# 3  4\n\nHindi[10]\n\nIndia\n\n4\n\n341\n\n4.429\n...
# 4  5\n\nBengali\n\nBangladesh\n\n4\n\n228\n\n2.96...
# 5  6\n\nPortuguese\n\nPortugal\n\n15\n\n221\n\n2....
# 6  7\n\nRussian\n\nRussian Federation\n\n19\n\n15...
# 7  8\n\nJapanese\n\nJapan\n\n2\n\n128\n\n1.662\n\...
# 8  9\n\nWestern Punjabi[11]\n\nPakistan\n\n2\n\n9...
# 9  10\n\nMarathi\n\nIndia\n\n1\n\n83.1\n\n1.079\n...

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
url = 'https://twitter.com/EvelienDonkers'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  
Tweets_done = soup.find_all('a', attrs = {'class': 'ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-nav'})
Tweets_done

Kinda_clean = [element.text for element in Tweets_done]
Find_numbers = re.findall('[0-9]+', ''.join(Kinda_clean))
Find_numbers
# Out:
# ['924']

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# Here I have the same problem as in the wikipedia one, I can't seem to get it in to a data frame. 
url = 'https://www.imdb.com/chart/top'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  
IBM_top_250 = [element.text.replace('\\n', ' ').replace('\\xa0', '').strip() for element in soup.find_all('tr')]
IBM_top_250 = [element.replace("\n \n\nSeen", " ").replace("\n\n\n\nNOT YET RELEASED", " ") for element in IBM_top_250]
IBM_top_250 = [element.replace("\xa012345678910  ", " ").replace("\n\n\n\n\n\n", " ") for element in IBM_top_250]
IBM_top_250 = [element.replace("\n      ", " ").replace("\n", " ") for element in IBM_top_250]    
IBM_top_250 = [element.replace("   ", " ") for element in IBM_top_250] 

colnames = IBM_top_250[0]
data = IBM_top_250[1:251]

df = pd.DataFrame(data, columns=colnames)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-184-9b8d99e0ec95> in <module>
#      15 data = IBM_top_250[1:251]
#      16
# ---> 17 df = pd.DataFrame(data, columns=colnames)
#      18 df
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     449                 else:
#     450                     mgr = init_ndarray(data, index, columns, dtype=dtype,
# --> 451                                        copy=copy)
#     452             else:
#     453                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     156                 raise_with_traceback(e)
#     157
# --> 158     index, columns = _get_axes(*values.shape, index=index, columns=columns)
# ...

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#still to do. 
url = 'https://www.imdb.com/search/title/?genres=biography&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=SCFD886QF4PA4TMV48WZ&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_4'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")  


soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Feature Film,
# Rating Count at least 25,000,
# Biography
# (Sorted by IMDb Rating Descending) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
# ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here

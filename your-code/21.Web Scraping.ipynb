# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import numpy as np
import datetime
from pandas.io.json import json_normalize

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %% [markdown]
# #### 1. Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools or clicking in 'Inspect' on any browser. Here is an example:
#
# ![title](example_1.png)
#
# 2. Use BeautifulSoup `find_all()` to extract all the html elements that contain the developer names. Hint: pass in the `attrs` parameter to specify the class.
#
# 3. Loop through the elements found and get the text for each of them.
#
# 4. While you are at it, use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names. Hint: you may also use `.get_text()` instead of `.text` and pass in the desired parameters to do some string manipulation (check the documentation).
#
# 5. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
'''
I have one doubt here: I am proposing this code because it looks simple and efficient but I am not sure whether it achieves the desired outcome.
Thus, some of the class names are not aligned with the html tag.
'''
names = [soup.find_all(class_='h3 lh-condensed')[i].get_text(strip=True) + ' '+'(' + 
         soup.find_all('p',{'class':'f4 text-normal mb-1'})[i].get_text(strip=True) + ')' for i in range(0,24)]
names
# Out:
# ['Márk Sági-Kazár (sagikazarmark)',
#  'Michele Locati (mlocati)',
#  'Frank Denis (jedisct1)',
#  'Lipis (lipis)',
#  'William Durand (willdurand)',
#  'Dawid Urbaniak (Trancever)',
#  'Alexey Pyltsyn (lex111)',
#  'Ian Storm Taylor (ianstormtaylor)',
#  'Stephen Celis (stephencelis)',
#  'Francois Zaninotto (fzaninotto)',
#  'PySimpleGUI (PySimpleGUI)',
#  'Toni de la Fuente (toniblyx)',
#  'Jake Vanderplas (jakevdp)',
#  'Stefan Prodan (stefanprodan)',
#  'chriseth (normanmaurer)',
#  'Norman Maurer (miekg)',
#  'Miek Gieben (stsrki)',
#  'Mladen Macanović (nschloe)',
#  'Nico Schlömer (arvidn)',
#  'Arvid Norberg (eamodio)',
#  'Eric Amodio (driesvints)',
#  'Dries Vints (nicolaskruchten)',
#  'Nicolas Kruchten (bernd)',
#  'Bernd Ahlers (mrdoob)']

# %%
'''
Therefore, I have tried a different way:
'''
text = soup.find_all('div',{'class':'col-md-6'})
'''
 I noticed that using the 'div' may lead to the inclusion of additional things that would need to be removed.
'''
clean_text = []
found = False
for elements in text:
    for string in elements:
         if str(string).find('"TRENDING_DEVELOPER"') != -1:
            clean_text.append(elements)
            break
'''
 After the above, we would need to parse the data. 
 This seems aligned with the content of the website. Please, kindly refer to the last update of the code and printing of the page.
'''
username = []
for i in range(len(clean_text)):
    username_parse = [element.strip() for element in clean_text[i].get_text().split("\n") if element != '']
    if len(username_parse) > 2:
        username.append(username_parse[0] + " (" + username_parse[2] + ")")
    else:
        username.append(username_parse[0])
        
username
# Out:
# ['Márk Sági-Kazár (sagikazarmark)',
#  'Michele Locati (mlocati)',
#  'Frank Denis (jedisct1)',
#  'Lipis (lipis)',
#  'William Durand (willdurand)',
#  'Dawid Urbaniak (Trancever)',
#  'Alexey Pyltsyn (lex111)',
#  'Ian Storm Taylor (ianstormtaylor)',
#  'Stephen Celis (stephencelis)',
#  'Francois Zaninotto (fzaninotto)',
#  'PySimpleGUI (PySimpleGUI)',
#  'Toni de la Fuente (toniblyx)',
#  'Jake Vanderplas (jakevdp)',
#  'Stefan Prodan (stefanprodan)',
#  'chriseth',
#  'Norman Maurer (normanmaurer)',
#  'Miek Gieben (miekg)',
#  'Mladen Macanović (stsrki)',
#  'Nico Schlömer (nschloe)',
#  'Arvid Norberg (arvidn)',
#  'Eric Amodio (eamodio)',
#  'Dries Vints (driesvints)',
#  'Nicolas Kruchten (nicolaskruchten)',
#  'Bernd Ahlers (bernd)',
#  'Mr.doob (mrdoob)']

# %% [markdown]
# #### 1.1. Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %%
text = soup.find_all('h1',{'class':"h3 lh-condensed"})
text[0].get_text()

srg_repos = []
for i in range(len(text)):
    srg_repos_parse = [element.strip() for element in text[i].get_text().replace("/","").split("\n") if element != '']
    srg_repos.append(srg_repos_parse[0] + " (" + srg_repos_parse[1] + ")")

srg_repos
# Out:
# ['carlospolop (hacktricks)',
#  'dagster-io (dagster)',
#  'django (django)',
#  'almarklein (timetagger)',
#  'mtlynch (tinypilot)',
#  'public-apis (public-apis)',
#  'DingXiaoH (RepVGG)',
#  'minimaxir (big-list-of-naughty-strings)',
#  'huggingface (transformers)',
#  'confluentinc (confluent-kafka-python)',
#  'JDAI-CV (FaceX-Zoo)',
#  'Trusted-AI (adversarial-robustness-toolbox)',
#  'tiangolo (fastapi)',
#  'ddbourgin (numpy-ml)',
#  'psf (black)',
#  'hodcroftlab (covariants)',
#  'locustio (locust)',
#  'owid (covid-19-data)',
#  'NVIDIA (apex)',
#  'faif (python-patterns)',
#  'd0nk (parler-tricks)',
#  'spack (spack)',
#  'scikit-learn (scikit-learn)',
#  'python-poetry (poetry)',
#  'SeanPedersen (HyperTag)']

# %% [markdown]
# #### 2. Display all the image links from Walt Disney wikipedia page.
# Hint: use `.get()` to access information inside tags. Check out the documentation.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

images = []
for img in soup.findAll('img'):
    images.append(img.get('src'))

images
# Out:
# ['//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/8/8c/Extended-protection-shackle.svg/20px-Extended-protection-shackle.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
# ...

# %% [markdown]
# #### 2.1. List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

count_language_box = soup.find_all(class_= 'central-featured-lang')
len(count_language_box)

count_language_box = [soup.find_all(class_= 'central-featured-lang')[i].get_text().replace('+','').replace('\xa0',',').replace('\n\n','') for i in range(0,len(count_language_box))]
count_language_box
# Out:
# ['English\n6,226,000 articles',
#  '日本語\n1,247,000 記事',
#  'Deutsch\n2,522,000 Artikel',
#  'Español\n1,652,000 artículos',
#  'Русский\n1,690,000 статей',
#  'Français\n2,287,000 articles',
#  'Italiano\n1,665,000 voci',
#  '中文\n1,169,000 條目',
#  'Português\n1,051,000 artigos',
#  'Polski\n1,448,000 haseł']

# %% [markdown]
# #### 2.2. Display the top 10 languages by number of native speakers stored in a pandas dataframe.
# Hint: After finding the correct table you want to analyse, you can use a nested **for** loop to find the elements row by row (check out the 'td' and 'tr' tags). <br>An easier way to do it is using pd.read_html(), check out documentation [here](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.read_html.html).

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here
data = pd.read_html(url)
data
#Not sure why it is not presenting the dataframe...
# Out:
# [    0                                                  1
#  0 NaN  This section needs to be updated. Please updat...,
#      Rank                            Language  Speakers(millions)  \
#  0      1                    Mandarin Chinese               918.0
#  1      2                             Spanish               480.0
#  2      3                             English               379.0
#  3      4  Hindi (sanskritised Hindustani)[9]               341.0
#  4      5                             Bengali               228.0
#  ..   ...                                 ...                 ...
#  86    87                               Czech                10.7
#  87    88                Taʽizzi-Adeni Arabic                10.5
#  88    89                              Uyghur                10.4
#  89    90                    Min Dong Chinese                10.3
#  90    91                             Sylheti                10.3
#
# ...

# %%
data1 = data[0]
data1.head(10)
# Out:
#     0                                                  1
# 0 NaN  This section needs to be updated. Please updat...

# %% [markdown]
# #### 3. Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.
# Hint: If you hover over the title of the movie, you should see the director's name. Can you find where it's stored in the html?

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here
import numpy as np

# %%
response = requests.get(url).content
soup = BeautifulSoup(response, 'lxml')

directors = soup.find_all('td',attrs = {'class':'titleColumn'})[0]
directors.find('a').get('title')
# Out:
# 'Frank Darabont (dir.), Tim Robbins, Morgan Freeman'

# %%
col_title = soup.select('td.titleColumn')
directors = [str(col_title[i]).split('title=')[1].split('(dir.)')[0].replace('"','').strip() for i in range(len(col_title))]
directors = pd.DataFrame(directors)

# %%
data = pd.read_html(url)[0]
data['Director Name'] = directors

# %%
def get_year_imdb(my_string):
    return int(re.findall('\d\d\d\d',my_string)[0])

def get_title_imdb(my_string):
    regex_string = re.findall('[^. (\d)]+',my_string)
    return " ".join(regex_string)

# %%
data['Initial Release'] = list(map(get_year_imdb,data['Rank & Title']))
data['Title'] = list(map(get_title_imdb,data['Rank & Title']))

# %%
data = data.drop(['Your Rating','Unnamed: 4','Unnamed: 0','Rank & Title'],axis=1)

# %%
data = data[['Title', 'Initial Release', 'Director Name', 'IMDb Rating']]
data
# Out:
#                                                  Title  Initial Release  \
# 0                             The Shawshank Redemption             1994
# 1                                        The Godfather             1972
# 2                               The Godfather: Part II             1974
# 3                                      The Dark Knight             2008
# 4                                            Angry Men             1957
# ..                                                 ...              ...
# 245                                           Drishyam             2015
# 246  Shin seiki Evangelion Gekijô-ban: Air/Magokoro...             1997
# 247                             La battaglia di Algeri             1966
# 248                                 The Princess Bride             1987
# 249                                        Mandariinid             2013
#
#             Director Name  IMDb Rating
# 0          Frank Darabont          9.2
# ...

# %% [markdown]
# #### 3.1. Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'https://www.imdb.com/list/ls009796553/'
response = requests.get(url).content
soup = BeautifulSoup(response, 'lxml')

# %%
my_class_lister_item_header = soup.find_all('h3',attrs = {'class':'lister-item-header'})[:10]
my_unnamed_class = soup.find_all("p", {"class":""})[:10]

# %%
movie_names_and_years = [my_class_lister_item_header[i].get_text().replace('\n',"") for i in range(len(my_class_lister_item_header))]
movie_year = list(map(get_year_imdb,movie_names_and_years))
movie_name = list(map(get_title_imdb,movie_names_and_years))

# %%
movie_description = [my_unnamed_class[i].get_text() for i in range(len(my_unnamed_class))]
movie_description = [movie_description[i].replace("\n","").strip() for i in range(len(movie_description))]

# %%
data = pd.DataFrame(list(zip(movie_name,movie_year,movie_description)),columns =['Name', 'Year', 'Description'])
data
# Out:
#                         Name  Year  \
# 0  A Nightmare on Elm Street  1984
# 1                 Awakenings  1990
# 2      A League of Their Own  1992
# 3               A Bronx Tale  1993
# 4     Angels in the Outfield  1994
# 5             A Time to Kill  1996
# 6                    Amistad  1997
# 7                   Anaconda  1997
# 8          A Cool, Dry Place  1998
# 9         American History X  1998
#
#                                          Description
# 0  The monstrous spirit of a slain child murderer...
# 1  The victims of an encephalitis epidemic many y...
# 2  Two sisters join the first female professional...
# 3  A father becomes worried when a local gangster...
# 4  When a boy prays for a chance to have a family...
# 5  In Canton, Mississippi, a fearless young lawye...
# 6  In 1839, the revolt of Mende captives aboard a...
# 7  A "National Geographic" film crew is taken hos...
# 8  Russell, single father balances his work as a ...
# ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'
# Out:
# Enter the city:  Luxembourg

# %%
# your code here
def weather(city):
    test = print(url)
    link = test
    page = requests.get(url)
    page.content
    soup = BeautifulSoup(page.content)
    converting = list(soup)
    converting2= str(page.content).split(",")
    description = converting2[4].split(":")[1].replace("'","")
    wind_Speed = converting2[14].split(":")[2]
    temperature = converting2[7].split(":")[2]
    return "Temperature: " +temperature + " Wind speed: " + wind_Speed + " Description: " + description

weather(city)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=Luxembourg&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric
# 'Temperature: -2.03 Wind speed: 0.45 Description: "overcast clouds"'

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
import requests
url = 'http://books.toscrape.com/'
page = requests.get(url)
page.content
soup = BeautifulSoup(page.content)
test = list(soup.children)

# %%
title = [soup.find_all('h3')[i].get_text() for i in range(0,20)]

price = [soup.find_all('p',{"class":"price_color"})[i].get_text().split("\n") for i in range(0,20)]
stock = [soup.find_all('p',{"class":"instock availability"})[i].get_text().replace("\n\n    \n        ","").replace("\n    \n","") for i in range(0,20)]

price2 = [y for x in price for y in x]

# %%
df = pd.DataFrame()

df["Title"]= title
df["Price"]=price2
df["Stock"]=stock

df
# Out:
#                                     Title   Price     Stock
# 0                      A Light in the ...  £51.77  In stock
# 1                      Tipping the Velvet  £53.74  In stock
# 2                              Soumission  £50.10  In stock
# 3                           Sharp Objects  £47.82  In stock
# 4            Sapiens: A Brief History ...  £54.23  In stock
# 5                         The Requiem Red  £22.65  In stock
# 6            The Dirty Little Secrets ...  £33.34  In stock
# 7                 The Coming Woman: A ...  £17.93  In stock
# 8                     The Boys in the ...  £22.60  In stock
# 9                         The Black Maria  £52.15  In stock
# 10  Starving Hearts (Triangular Trade ...  £13.99  In stock
# 11                  Shakespeare's Sonnets  £20.66  In stock
# 12                            Set Me Free  £17.46  In stock
# 13    Scott Pilgrim's Precious Little ...  £52.29  In stock
# 14                      Rip it Up and ...  £35.02  In stock
# ...

# %% [markdown]
# ####  Display the 100 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.
# ***Hint:*** Here the displayed number of earthquakes per page is 20, but you can easily move to the next page by looping through the desired number of pages and adding it to the end of the url.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/?view='

# This is how you will loop through each page:
number_of_pages = int(100/20)
each_page_urls = []

for n in range(1, number_of_pages+1):
    link = url+str(n)
    each_page_urls.append(link)
    
each_page_urls
# Out:
# ['https://www.emsc-csem.org/Earthquake/?view=1',
#  'https://www.emsc-csem.org/Earthquake/?view=2',
#  'https://www.emsc-csem.org/Earthquake/?view=3',
#  'https://www.emsc-csem.org/Earthquake/?view=4',
#  'https://www.emsc-csem.org/Earthquake/?view=5']

# %%
# your code here

url1 = 'https://www.emsc-csem.org/Earthquake/?view=1'
url2 = 'https://www.emsc-csem.org/Earthquake/?view=2'
url3 = 'https://www.emsc-csem.org/Earthquake/?view=3'
url4 = 'https://www.emsc-csem.org/Earthquake/?view=4'
url5 = 'https://www.emsc-csem.org/Earthquake/?view=5'
page = requests.get(url)
 
page.content

soup = BeautifulSoup(page.content)

test = list(soup.children)


data1 = pd.read_html(url1)
data2 = pd.read_html(url2)
data3 = pd.read_html(url3)
data4 = pd.read_html(url4)
data5 = pd.read_html(url5)


data_earthquaks = data1[3]

earthquakes = pd.DataFrame()

earthquakes["Dates & time"] = data_earthquaks["Date & Time UTC"]["12345678910»"]
earthquakes["Latitude"] = data_earthquaks["Latitude degrees"]["12345678910»"]
earthquakes["Latitude2"] = data_earthquaks["Latitude degrees"]["12345678910».1"]
earthquakes["Longitud"] = data_earthquaks["Longitude degrees"]["12345678910»"]
earthquakes["Longitud2"] = data_earthquaks["Longitude degrees"]["12345678910».1"]
earthquakes["Region Name"] = data_earthquaks["Last update [-]"]["12345678910»"]

# %%
earthquakes
# Out:
#                           Dates & time       Latitude      Latitude2  \
# 0       2021-01-16 10:28:02.208min ago          38.94              N
# 1       2021-01-16 10:18:44.017min ago          45.61              N
# 2       2021-01-16 09:59:30.636min ago          45.43              N
# 3       2021-01-16 09:56:13.839min ago          37.90              N
# 4       2021-01-16 09:43:14.552min ago          37.57              N
# 5       2021-01-16 09:42:30.053min ago          35.88              N
# 6       2021-01-16 09:42:18.253min ago          30.58              S
# 7   2021-01-16 09:31:13.21hr 04min ago          17.98              N
# 8   2021-01-16 09:29:54.41hr 06min ago          19.17              N
# 9   2021-01-16 09:26:45.31hr 09min ago           6.20              S
# 10  2021-01-16 09:08:06.01hr 28min ago          33.58              S
# 11  2021-01-16 09:03:23.01hr 32min ago          31.02              S
# 12  2021-01-16 08:57:56.71hr 38min ago          37.24              N
# ...

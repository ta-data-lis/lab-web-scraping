# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here
response = requests.get(url)
response.raise_for_status()
webpage = response.text
soup = BeautifulSoup(webpage, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %% [markdown]
# #### 1. Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools or clicking in 'Inspect' on any browser. Here is an example:
#
# ![title](example_1.png)
#
# 2. Use BeautifulSoup `find_all()` to extract all the html elements that contain the developer names. Hint: pass in the `attrs` parameter to specify the class.
#
# 3. Loop through the elements found and get the text for each of them.
#
# 4. While you are at it, use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names. Hint: you may also use `.get_text()` instead of `.text` and pass in the desired parameters to do some string manipulation (check the documentation).
#
# 5. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
h1_tags = soup.find_all('h1', {'class': 'h3 lh-condensed'})
developer_names = []
for name in h1_tags:
    developer_names.append(name.text.strip())
developer_names
# Out:
# ['Joe Tsai',
#  'Joe Previte',
#  'Joe Chen',
#  'Casey Rodarmor',
#  'daquexian',
#  'Magnus Edenhill',
#  'Yo-An Lin',
#  'Minko Gechev',
#  'Logan McAnsh',
#  'Kent C. Dodds',
#  'Marten Seemann',
#  'Julien Viet',
#  'Jeffrey Su',
#  'Agniva De Sarker',
#  'Stephen Roller',
#  'Trask Stalnaker',
#  '二货机器人',
#  'Dominic Gannaway',
#  'Helio Machado',
#  'Peach',
#  'Andrey Helldar',
#  'Dylan J. Sather',
#  'Martin Fleischmann',
#  'Nathan Rajlich',
#  'Amruth Pillai']

# %% [markdown]
# #### 1.1. Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
# your code here
response = requests.get(url)
response.raise_for_status()
webpage = response.text
soup = BeautifulSoup(webpage, "html.parser")
h1_tags = soup.find_all('h1', {'class': 'h3 lh-condensed'})
repo_names = []
for name in h1_tags:
    name = name.text.strip()
    name = name.replace("\n", "")
    name = name.replace("   ", "")
    repo_names.append(name)
repo_names
# Out:
# ['projectdiscovery /nuclei-templates',
#  'sqlfluff /sqlfluff',
#  'ageitgey /face_recognition',
#  'ultralytics /yolov5',
#  'yanx27 /Pointnet_Pointnet2_pytorch',
#  'saleor /saleor',
#  'commaai /calib_challenge',
#  'JacobSterns /Solana-mint-bot',
#  'gunnar63 /magiceden-minting-bot',
#  'RhinoSecurityLabs /pacu',
#  'MrMimic /data-scientist-roadmap',
#  'ebankoff /Beast_Bomber',
#  'aws /aws-cli',
#  'Datalux /Osintgram',
#  'TheAlgorithms /Python',
#  'mikeroyal /Digital-Forensics-Guide',
#  'espnet /espnet',
#  'babysor /MockingBird',
#  'KasRoudra /PyPhisher',
#  'psf /black',
#  'fighting41love /funNLP',
#  'jina-ai /dalle-flow',
#  'kxxt /aspeak',
#  'MIC-DKFZ /nnUNet',
#  'SkywalkerJi /mdt']

# %% [markdown]
# #### 2. Display all the image links from Walt Disney wikipedia page.
# Hint: use `.get()` to access information inside tags. Check out the documentation.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here
response = requests.get(url)
response.raise_for_status()
webpage = response.text
soup = BeautifulSoup(webpage, "html.parser")
a_tags = soup.find_all('a', {'class': 'image'})
image_links = []
for link in a_tags:
    image_links.append(f"{link['href']}")
image_links
    

#Check if work correct
#print(len(image_links))
#import webbrowser
#for link in image_links:
#    webbrowser.open("https://www.wikipedia.org" + link)
# Out:
# ['/wiki/File:Walt_Disney_1946.JPG',
#  '/wiki/File:Walt_Disney_1942_signature.svg',
#  '/wiki/File:Walt_Disney_envelope_ca._1921.jpg',
#  '/wiki/File:Trolley_Troubles_poster.jpg',
#  '/wiki/File:Steamboat-willie.jpg',
#  '/wiki/File:Walt_Disney_1935.jpg',
#  '/wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg',
#  '/wiki/File:Disney_drawing_goofy.jpg',
#  '/wiki/File:DisneySchiphol1951.jpg',
#  '/wiki/File:WaltDisneyplansDisneylandDec1954.jpg',
#  '/wiki/File:Walt_disney_portrait_right.jpg',
#  '/wiki/File:Walt_Disney_Grave.JPG',
#  '/wiki/File:Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  '/wiki/File:Disney_Oscar_1953_(cropped).jpg',
#  '/wiki/File:Disney1968.jpg',
#  '/wiki/File:Disneyland_Resort_logo.svg',
#  '/wiki/File:Animation_disc.svg',
#  '/wiki/File:P_vip.svg',
#  '/wiki/File:Magic_Kingdom_castle.jpg',
#  '/wiki/File:Video-x-generic.svg',
#  '/wiki/File:Flag_of_Los_Angeles_County,_California.svg',
#  '/wiki/File:Blank_television_set.svg',
# ...

# %% [markdown]
# #### 2.1. List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here
response = requests.get(url)
response.raise_for_status()
webpage = response.content
webpage = webpage.decode('utf-8')
soup = BeautifulSoup(webpage, "html.parser")
div_tags = soup.find_all('div', {'class': 'central-featured-lang'})
languages = []
no_of_articles = []

for tag in div_tags:
    language = tag.select('strong')
    languages.append(language[0].text)
    article_no = tag.select('bdi')
    article_no = article_no[0].text
    article_no = article_no.replace('\xa0','')
    no_of_articles.append(article_no)

data = {
    'Language_names':languages,
    'No_of_articles':no_of_articles,
}
import pandas
df = pd.DataFrame(data)
df
# Out:
#   Language_names No_of_articles
# 0        English       6458000+
# 1        Русский       1798000+
# 2            日本語       1314000+
# 3        Deutsch       2667000+
# 4        Español       1755000+
# 5       Français       2400000+
# 6             中文       1256000+
# 7       Italiano       1742000+
# 8      Português       1085000+
# 9         Polski       1512000+

# %% [markdown]
# #### 2.2. Display the top 10 languages by number of native speakers stored in a pandas dataframe.
# Hint: After finding the correct table you want to analyse, you can use a nested **for** loop to find the elements row by row (check out the 'td' and 'tr' tags). <br>An easier way to do it is using pd.read_html(), check out documentation [here](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.read_html.html).

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here
import pandas as pd
tables = pd.read_html(url, match="Languages with at least 10 million first-language speakers")
len(tables)
df = tables[0]
df.head(10)
# Out:
#    Rank                             Language Speakers(millions)  \
# 0     1                     Mandarin Chinese                918
# 1     2                              Spanish                480
# 2     3                              English                379
# 3     4  Hindi (sanskritised Hindustani)[11]                341
# 4     5                              Bengali                300
# 5     6                           Portuguese                221
# 6     7                              Russian                154
# 7     8                             Japanese                128
# 8     9                  Western Punjabi[12]               92.7
# 9    10                              Marathi               83.1
#
#   Percentageof world pop.(March 2019)[10] Language family        Branch
# 0                                 11.922%    Sino-Tibetan       Sinitic
# 1                                  5.994%   Indo-European       Romance
# ...

# %% [markdown]
# #### 3. Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.
# Hint: If you hover over the title of the movie, you should see the director's name. Can you find where it's stored in the html?

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here
response = requests.get(url)
response.raise_for_status()
webpage = response.content
webpage = webpage.decode('utf-8')
soup = BeautifulSoup(webpage, "html.parser")

a_tags = soup.select('td.titleColumn > a')
span_tags = soup.find_all('span', {'class':'secondaryInfo'})

# %%
movie_names = []
#initial_release
#director_name
#stars
for tag in a_tags:
    name = tag.text.strip()
    movie_names.append(name)
movie_names
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Dark Knight',
#  'The Godfather: Part II',
#  '12 Angry Men',
#  "Schindler's List",
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Il buono, il brutto, il cattivo',
#  'Forrest Gump',
#  'Fight Club',
#  'Inception',
#  'The Lord of the Rings: The Two Towers',
#  'The Empire Strikes Back',
#  'The Matrix',
#  'Goodfellas',
#  "One Flew Over the Cuckoo's Nest",
#  'Se7en',
#  'Shichinin no samurai',
#  "It's a Wonderful Life",
#  'The Silence of the Lambs',
#  'Cidade de Deus',
#  'Saving Private Ryan',
#  'La vita è bella',
#  'The Green Mile',
#  'Star Wars',
#  'Interstellar',
#  'Terminator 2: Judgment Day',
#  'Back to the Future',
#  'Sen to Chihiro no kamikakushi',
#  'Psycho',
#  'The Pianist',
#  'Léon',
#  'Gisaengchung',
#  'The Lion King',
#  'American History X',
#  'Gladiator',
#  'The Usual Suspects',
#  'The Departed',
# ...

# %% [markdown]
# #### 3.1. Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'https://www.imdb.com/list/ls009796553/'

# %%
# your code here
response = requests.get(url)
response.raise_for_status()
webpage = response.content
webpage = webpage.decode('utf-8')
soup = BeautifulSoup(webpage, "html.parser")

h3_tags = soup.find_all('h3', {'class': 'lister-item-header'})
div_tags = soup.find_all('div', {'class':'lister-item-content'})

import re
movie_names = []
movie_years = []
movie_summaries = []

for tag in h3_tags:
    name = tag.select('a')
    name = name[0].text
    movie_names.append(name)
    year = tag.select('span')
    year = year[1].text
    rule = '[()]|(Video)|I'
    year = re.sub(rule,'',year)
    year = re.sub(rule,'',year)
    year = year.strip()
    movie_years.append(year)


for tag in div_tags:
    summary = tag.select('div > p')
    summary = summary[1].text
    summary = summary.replace('\n', '')
    movie_summaries.append(summary)

data = {
    "Movie_name":movie_names,
    "Movie_year":movie_years,
    "Movie_summary":movie_summaries
}

df = pd.DataFrame(data)
df.head(10)
# Out:
#                   Movie_name Movie_year  \
# 0  A Nightmare on Elm Street       1984
# 1                 Awakenings       1990
# 2      A League of Their Own       1992
# 3               A Bronx Tale       1993
# 4     Angels in the Outfield       1994
# 5             A Time to Kill       1996
# 6                    Amistad       1997
# 7                   Anaconda       1997
# 8          A Cool, Dry Place       1998
# 9         American History X       1998
#
#                                        Movie_summary
# 0  Teenager Nancy Thompson must uncover the dark ...
# 1  The victims of an encephalitis epidemic many y...
# 2  Two sisters join the first female professional...
# 3  A father becomes worried when a local gangster...
# 4  When a boy prays for a chance to have a family...
# 5  In Canton, Mississippi, a fearless young lawye...
# 6  In 1839, the revolt of Mende captives aboard a...
# 7  A "National Geographic" film crew is taken hos...
# ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID={4068d8877c7cb848a05ad166d359e9dd}'
# Out:
# Enter the city: Lagos

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here

# %% [markdown]
# ####  Display the 100 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.
# ***Hint:*** Here the displayed number of earthquakes per page is 20, but you can easily move to the next page by looping through the desired number of pages and adding it to the end of the url.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/?view='

# This is how you will loop through each page:
number_of_pages = int(100/20)
each_page_urls = []

for n in range(1, number_of_pages+1):
    link = url+str(n)
    each_page_urls.append(link)
    
each_page_urls

# %%
# your code here
